# %% [markdown]
# # Llama 3.1 Rag Agent with LlamaIndex
#
# <a target="_blank" href="https://colab.research.google.com/github/ytang07/ai_agents_cookbooks/blob/main/llamaindex/llama31_8b_rag_agent.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# This notebook will walk you through building a LlamaIndex ReactAgent using Llama 3.1 70b. We will be using [OctoAI](https://octo.ai) as our embeddings and llm provider.
#
# ## Install Dependencies

# %%
! pip install -qU llama-index llama-index-llms-openai llama-index-readers-file octoai llama-index-llms-octoai llama-index-embeddings-octoai llama-index-embeddings-openai llama-index-llms-openai-like

! pip freeze llama-index-core
! pip freeze embeddings-openai
# Out:
# aiohappyeyeballs==2.4.0
# aiohttp==3.10.5
# aiosignal==1.3.1
# annotated-types==0.7.0
# anyio==4.4.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.4.1
# async-lru==2.0.4
# attrs==24.2.0
# babel==2.16.0
# beautifulsoup4==4.12.3
# bleach==6.1.0
# boto3==1.35.5
# boto3-stubs==1.35.5
# botocore==1.35.5
# botocore-stubs==1.35.5
# by==0.0.4
# certifi==2024.7.4
# cffi==1.17.0
# chainmap==1.0.3
# charset-normalizer==3.3.2
# click==8.1.7
# colorama==0.4.6
# combomethod==1.0.12
# comm==0.2.2
# dataclasses-json==0.6.7
# debugpy==1.8.5
# decorator==5.1.1
# defusedxml==0.7.1
# Deprecated==1.2.14
# dirtyjson==1.0.8
# distro==1.9.0
# docutils==0.21.2
# executing==2.0.1
# fastjsonschema==2.20.0
# filelock==3.15.4
# fqdn==1.5.1
# frozenlist==1.4.1
# fsspec==2024.6.1
# greenlet==3.0.3
# h11==0.14.0
# httpcore==1.0.5
# httpx==0.27.0
# httpx-sse==0.4.0
# huggingface-hub==0.24.6
# idna==3.8
# ipykernel==6.29.5
# ipython==8.26.0
# ipywidgets==8.1.5
# isoduration==20.11.0
# jedi==0.19.1
# Jinja2==3.1.4
# jiter==0.5.0
# jmespath==1.0.1
# joblib==1.4.2
# json5==0.9.25
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2023.12.1
# jupyter==1.0.0
# jupyter-console==6.6.3
# jupyter-events==0.10.0
# jupyter-lsp==2.2.5
# jupyter_client==8.6.2
# jupyter_core==5.7.2
# jupyter_server==2.14.2
# jupyter_server_terminals==0.5.3
# jupyterlab==4.2.4
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.27.3
# jupyterlab_widgets==3.0.13
# llama-cloud==0.0.15
# llama-index==0.11.1
# llama-index-agent-openai==0.3.0
# llama-index-cli==0.3.0
# llama-index-core==0.11.1
# llama-index-embeddings-octoai==0.2.0
# llama-index-embeddings-openai==0.2.3
# llama-index-indices-managed-llama-cloud==0.3.0
# llama-index-legacy==0.9.48.post3
# llama-index-llms-octoai==0.2.0
# llama-index-llms-openai==0.2.0
# llama-index-llms-openai-like==0.2.0
# llama-index-multi-modal-llms-openai==0.2.0
# llama-index-program-openai==0.2.0
# llama-index-question-gen-openai==0.2.0
# llama-index-readers-file==0.2.0
# llama-index-readers-llama-parse==0.2.0
# llama-parse==0.5.0
# load-dotenv==0.1.0
# lockfile==0.12.2
# MarkupSafe==2.1.5
# marshmallow==3.22.0
# matplotlib-inline==0.1.7
# mistune==3.0.2
# multidict==6.0.5
# mypy-extensions==1.0.0
# nbclient==0.10.0
# nbconvert==7.16.4
# nbformat==5.10.4
# nest-asyncio==1.6.0
# networkx==3.3
# nltk==3.9.1
# notebook==7.2.1
# notebook_shim==0.2.4
# nulltype==2.3.1
# numpy==1.26.4
# octoai==1.6.0
# openai==1.42.0
# options==1.4.10
# outcome==1.3.0.post0
# overrides==7.7.0
# packaging==24.1
# pandas==2.2.2
# pandocfilters==1.5.1
# parso==0.8.4
# pid==3.0.4
# pillow==10.4.0
# platformdirs==4.2.2
# prometheus_client==0.20.0
# prompt_toolkit==3.0.47
# psutil==6.0.0
# pure_eval==0.2.3
# pycparser==2.22
# pydantic==2.8.2
# pydantic_core==2.20.1
# Pygments==2.18.0
# pypdf==4.3.1
# PySocks==1.7.1
# python-daemon==3.0.1
# python-dateutil==2.9.0.post0
# python-dotenv==1.0.1
# python-json-logger==2.0.7
# pytz==2024.1
# pywin32==306
# pywinpty==2.0.13
# PyYAML==6.0.2
# pyzmq==26.2.0
# qtconsole==5.5.2
# QtPy==2.4.1
# referencing==0.35.1
# regex==2024.7.24
# requests==2.32.3
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rpds-py==0.20.0
# s3transfer==0.10.2
# safetensors==0.4.4
# selenium==4.23.1
# Send2Trash==1.8.3
# service==0.6.0
# setproctitle==1.3.3
# setuptools==73.0.1
# six==1.12.0
# sniffio==1.3.1
# sortedcontainers==2.4.0
# soupsieve==2.6
# SQLAlchemy==2.0.32
# stack-data==0.6.3
# striprtf==0.0.26
# tenacity==8.5.0
# terminado==0.18.1
# tiktoken==0.7.0
# tinycss2==1.3.0
# tokenizers==0.19.1
# tornado==6.4.1
# tqdm==4.66.5
# traitlets==5.14.3
# transformers==4.44.2
# trio==0.26.2
# trio-websocket==0.11.1
# types-awscrt==0.21.2
# types-boto3==1.0.2
# types-python-dateutil==2.9.0.20240821
# types-s3transfer==0.10.1
# typing-inspect==0.9.0
# typing_extensions==4.12.2
# tzdata==2024.1
# uri-template==1.3.0
# urllib3==2.2.2
# wcwidth==0.2.13
# webcolors==24.8.0
# webencodings==0.5.1
# websocket-client==1.8.0
# widgetsnbextension==4.0.13
# wrapt==1.16.0
# wsproto==1.2.0
# yarl==1.9.4
# aiohappyeyeballs==2.4.0
# aiohttp==3.10.5
# aiosignal==1.3.1
# annotated-types==0.7.0
# anyio==4.4.0
# argon2-cffi==23.1.0
# argon2-cffi-bindings==21.2.0
# arrow==1.3.0
# asttokens==2.4.1
# async-lru==2.0.4
# attrs==24.2.0
# babel==2.16.0
# beautifulsoup4==4.12.3
# bleach==6.1.0
# boto3==1.35.5
# boto3-stubs==1.35.5
# botocore==1.35.5
# botocore-stubs==1.35.5
# by==0.0.4
# certifi==2024.7.4
# cffi==1.17.0
# chainmap==1.0.3
# charset-normalizer==3.3.2
# click==8.1.7
# colorama==0.4.6
# combomethod==1.0.12
# comm==0.2.2
# dataclasses-json==0.6.7
# debugpy==1.8.5
# decorator==5.1.1
# defusedxml==0.7.1
# Deprecated==1.2.14
# dirtyjson==1.0.8
# distro==1.9.0
# docutils==0.21.2
# executing==2.0.1
# fastjsonschema==2.20.0
# filelock==3.15.4
# fqdn==1.5.1
# frozenlist==1.4.1
# fsspec==2024.6.1
# greenlet==3.0.3
# h11==0.14.0
# httpcore==1.0.5
# httpx==0.27.0
# httpx-sse==0.4.0
# huggingface-hub==0.24.6
# idna==3.8
# ipykernel==6.29.5
# ipython==8.26.0
# ipywidgets==8.1.5
# isoduration==20.11.0
# jedi==0.19.1
# Jinja2==3.1.4
# jiter==0.5.0
# jmespath==1.0.1
# joblib==1.4.2
# json5==0.9.25
# jsonpointer==3.0.0
# jsonschema==4.23.0
# jsonschema-specifications==2023.12.1
# jupyter==1.0.0
# jupyter-console==6.6.3
# jupyter-events==0.10.0
# jupyter-lsp==2.2.5
# jupyter_client==8.6.2
# jupyter_core==5.7.2
# jupyter_server==2.14.2
# jupyter_server_terminals==0.5.3
# jupyterlab==4.2.4
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.27.3
# jupyterlab_widgets==3.0.13
# llama-cloud==0.0.15
# llama-index==0.11.1
# llama-index-agent-openai==0.3.0
# llama-index-cli==0.3.0
# llama-index-core==0.11.1
# llama-index-embeddings-octoai==0.2.0
# llama-index-embeddings-openai==0.2.3
# llama-index-indices-managed-llama-cloud==0.3.0
# llama-index-legacy==0.9.48.post3
# llama-index-llms-octoai==0.2.0
# llama-index-llms-openai==0.2.0
# llama-index-llms-openai-like==0.2.0
# llama-index-multi-modal-llms-openai==0.2.0
# llama-index-program-openai==0.2.0
# llama-index-question-gen-openai==0.2.0
# llama-index-readers-file==0.2.0
# llama-index-readers-llama-parse==0.2.0
# llama-parse==0.5.0
# load-dotenv==0.1.0
# lockfile==0.12.2
# MarkupSafe==2.1.5
# marshmallow==3.22.0
# matplotlib-inline==0.1.7
# mistune==3.0.2
# multidict==6.0.5
# mypy-extensions==1.0.0
# nbclient==0.10.0
# nbconvert==7.16.4
# nbformat==5.10.4
# nest-asyncio==1.6.0
# networkx==3.3
# nltk==3.9.1
# notebook==7.2.1
# notebook_shim==0.2.4
# nulltype==2.3.1
# numpy==1.26.4
# octoai==1.6.0
# openai==1.42.0
# options==1.4.10
# outcome==1.3.0.post0
# overrides==7.7.0
# packaging==24.1
# pandas==2.2.2
# pandocfilters==1.5.1
# parso==0.8.4
# pid==3.0.4
# pillow==10.4.0
# platformdirs==4.2.2
# prometheus_client==0.20.0
# prompt_toolkit==3.0.47
# psutil==6.0.0
# pure_eval==0.2.3
# pycparser==2.22
# pydantic==2.8.2
# pydantic_core==2.20.1
# Pygments==2.18.0
# pypdf==4.3.1
# PySocks==1.7.1
# python-daemon==3.0.1
# python-dateutil==2.9.0.post0
# python-dotenv==1.0.1
# python-json-logger==2.0.7
# pytz==2024.1
# pywin32==306
# pywinpty==2.0.13
# PyYAML==6.0.2
# pyzmq==26.2.0
# qtconsole==5.5.2
# QtPy==2.4.1
# referencing==0.35.1
# regex==2024.7.24
# requests==2.32.3
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rpds-py==0.20.0
# s3transfer==0.10.2
# safetensors==0.4.4
# selenium==4.23.1
# Send2Trash==1.8.3
# service==0.6.0
# setproctitle==1.3.3
# setuptools==73.0.1
# six==1.12.0
# sniffio==1.3.1
# sortedcontainers==2.4.0
# soupsieve==2.6
# SQLAlchemy==2.0.32
# stack-data==0.6.3
# striprtf==0.0.26
# tenacity==8.5.0
# terminado==0.18.1
# tiktoken==0.7.0
# tinycss2==1.3.0
# tokenizers==0.19.1
# tornado==6.4.1
# tqdm==4.66.5
# traitlets==5.14.3
# transformers==4.44.2
# trio==0.26.2
# trio-websocket==0.11.1
# types-awscrt==0.21.2
# types-boto3==1.0.2
# types-python-dateutil==2.9.0.20240821
# types-s3transfer==0.10.1
# typing-inspect==0.9.0
# typing_extensions==4.12.2
# tzdata==2024.1
# uri-template==1.3.0
# urllib3==2.2.2
# wcwidth==0.2.13
# webcolors==24.8.0
# webencodings==0.5.1
# websocket-client==1.8.0
# widgetsnbextension==4.0.13
# wrapt==1.16.0
# wsproto==1.2.0
# yarl==1.9.4
# Requirement already satisfied: load_dotenv in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (0.1.0)
# Requirement already satisfied: python-dotenv in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from load_dotenv) (1.0.1)
# Requirement already satisfied: selenium in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (4.23.1)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.2)
# Requirement already satisfied: trio~=0.17 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from selenium) (0.26.2)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from selenium) (2024.7.4)
# Requirement already satisfied: typing_extensions~=4.9 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (24.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (3.8)
# Requirement already satisfied: outcome in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from trio~=0.17->selenium) (1.17.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.22)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Requirement already satisfied: Service in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (0.6.0)
# Requirement already satisfied: pid>=2.2.3 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from Service) (3.0.4)
# Requirement already satisfied: python-daemon>=2.1.2 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from Service) (3.0.1)
# Requirement already satisfied: setproctitle>=1.1.10 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from Service) (1.3.3)
# Requirement already satisfied: psutil>=5.4.8 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from pid>=2.2.3->Service) (6.0.0)
# Requirement already satisfied: docutils in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from python-daemon>=2.1.2->Service) (0.21.2)
# Requirement already satisfied: lockfile>=0.10 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from python-daemon>=2.1.2->Service) (0.12.2)
# Requirement already satisfied: setuptools>=62.4.0 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from python-daemon>=2.1.2->Service) (73.0.1)
# Requirement already satisfied: Options in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (1.4.10)
# Requirement already satisfied: chainmap~=1.0.3 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from Options) (1.0.3)
# Requirement already satisfied: combomethod~=1.0.12 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from Options) (1.0.12)
# Requirement already satisfied: nulltype~=2.3.1 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from Options) (2.3.1)
# Requirement already satisfied: six~=1.12.0 in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (from Options) (1.12.0)
# Requirement already satisfied: By in c:\users\billm\appdata\local\programs\python\python312\lib\site-packages (0.0.4)

# %% [markdown]
# ## Setup API Keys
# To run the rest of the notebook you will need access to an OctoAI API key. You can sign up for an account [here](https://octoai.cloud/). If you need further guidance you can check OctoAI's [documentation page](https://octo.ai/docs/getting-started/how-to-create-octoai-access-token).

# %%
from os import environ
from getpass import getpass
environ["OCTOAI_API_KEY"] = getpass("Input your OCTOAI API key: ")
from dotenv import load_dotenv

load_dotenv()

OCTOAI_API_KEY = environ["OCTOAI_API_KEY"]

# %% [markdown]
# ## Import libraries and setup LlamaIndex

# %%
from llama_index.core import (
    SimpleDirectoryReader,
    VectorStoreIndex,
    StorageContext,
    load_index_from_storage,
)
from llama_index.core.tools import QueryEngineTool, ToolMetadata
from llama_index.embeddings.octoai import OctoAIEmbedding
from llama_index.core import Settings as LlamaGlobalSettings
from llama_index.core.agent import ReActAgent
from llama_index.llms.openai_like import OpenAILike

# Set the default model to use for embeddings
LlamaGlobalSettings.embed_model = OctoAIEmbedding()

# Create an llm object to use for the QueryEngine and the ReActAgent
llm = OpenAILike(
    model="meta-llama-3.1-70b-instruct",
    api_base="https://text.octoai.run/v1",
    api_key=environ["OCTOAI_API_KEY"],
    context_window=40000,
    is_function_calling_model=True,
    is_chat_model=True,
)
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %% [markdown]
# ## Load Documents

# %%
try:
    storage_context = StorageContext.from_defaults(
        persist_dir="./storage/disease"
    )
    disease_index = load_index_from_storage(storage_context)

    storage_context = StorageContext.from_defaults(
        persist_dir="./storage/treatments"
    )
    treatment_index = load_index_from_storage(storage_context)

    index_loaded = True
except:
    index_loaded = False

# %% [markdown]
# This is the point we create our vector indexes, by calculating the embedding vectors for each of the chunks. You only need to run this once.

# %%
#if not index_loaded:

import os

# Get the current directory
current_directory = os.getcwd()

# load data
disease_docs = SimpleDirectoryReader(
    input_files=["./Disease_symptom_and_patient_profile_dataset_flat.csv"]
).load_data()

treatments_docs = SimpleDirectoryReader(
    input_files=["./Disease_treatments_flat.csv"]
).load_data()

# build index
disease_index = VectorStoreIndex.from_documents(disease_docs, show_progress=True)
treatments_index = VectorStoreIndex.from_documents(treatments_docs, show_progress=True)

# persist index
disease_index.storage_context.persist(persist_dir="./storage/disease")
treatments_index.storage_context.persist(persist_dir="./storage/treatments")
# Out:
# Parsing nodes:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/14 [00:00<?, ?it/s]
# Parsing nodes:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating embeddings:   0%|          | 0/3 [00:00<?, ?it/s]

# %% [markdown]
# Now create the query engines.

# %%
disease_engine = disease_index.as_query_engine(similarity_top_k=3, llm=llm)
treatments_engine = treatments_index.as_query_engine(similarity_top_k=3, llm=llm)

# %% [markdown]
# We can now define the query engines as tools that will be used by the agent.
#
# As there is a query engine per document we need to also define one tool for each of them.

# %%
query_engine_tools = [
    QueryEngineTool(
        query_engine=disease_engine,
        metadata=ToolMetadata(
            name="disease_csv",
            description=(
                "Provides symptom and disease data from many patients."
                "Use a detailed plain text question as input to the tool."
            ),
        ),
    ),
    QueryEngineTool(
        query_engine=treatments_engine,
        metadata=ToolMetadata(
            name="treatments_csv",
            description=(
                "Provides diseases and matching treatment recommendations."
                "Use a detailed plain text question as input to the tool."
            ),
        ),
    )
]

# %% [markdown]
# ## Creating the Agent
# Now we have all the elements to create a LlamaIndex ReactAgent

# %%
agent = ReActAgent.from_tools(
    query_engine_tools,
    llm=llm,
    verbose=True,
    max_turns=10,
)

# %% [markdown]
# Now we can interact with the agent and ask a question.

# %%
prompt1 = input("what are your symptoms to diognise?")


response = agent.chat(prompt1)
print(str(response))
# Out:
# > Running step d169f815-1275-4026-a6a4-a3a9382f3217. Step input: i have fever and cough no fatigue and low blood pressure
# Thought: The current language of the user is: English. I need to use a tool to help me narrow down the possible diseases based on the symptoms provided.
# Action: disease_csv
# Action Input: {'input': 'fever and cough and no fatigue and low blood pressure'}
# Observation: None
# > Running step a3b02b53-e825-484a-a1e3-f53f16fd5e0b. Step input: None
# Thought: The disease_csv tool did not return any results. I will try rephrasing the input to see if I can get any results.
# Action: disease_csv
# Action Input: {'input': 'fever, cough, no fatigue, low blood pressure'}
# Observation: Anxiety Disorders
# > Running step 2ebfba44-eaee-4c4f-a081-75bb121936cd. Step input: None
# Thought: The disease_csv tool returned Anxiety Disorders as a possible match, but I'm not sure if this is the correct diagnosis. I would like to explore other possibilities by using the treatments_csv tool to see if there are any other diseases that match the symptoms provided.
# Action: treatments_csv
# Action Input: {'input': 'fever and cough and no fatigue and low blood pressure'}
# Observation: Based on the provided information, the treatment for Influenza is to Play Ghost of Tsushima.
# > Running step 677c0ec1-8024-4d25-8e48-0442aa37c2b0. Step input: None
# Thought: The treatments_csv tool returned a treatment for Influenza, which seems like a more plausible match for the symptoms provided (fever and cough) than Anxiety Disorders. However, the treatment recommendation seems unrelated to the disease. I will try to find a more accurate treatment recommendation for Influenza.
# Action: treatments_csv
# Action Input: {'input': 'Influenza treatment'}
# Observation: Play Ghost of Tsushima
# > Running step 744365ad-9cf6-4643-b984-1a3020b3cb8b. Step input: None
# Thought: The treatments_csv tool again returned an unrelated treatment recommendation for Influenza. I will try to find a more accurate treatment recommendation by rephrasing the input.
# Action: treatments_csv
# Action Input: {'input': 'What are the treatment options for Influenza?'}
# Observation: The treatment options for Influenza are to Play Ghost of Tsushima.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 4
#       1 prompt1 = input("what are your symptoms to diognise?")
# ----> 4 response = agent.chat(prompt1)
#       5 print(str(response))
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:261, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     253 self.span_enter(
#     254     id_=id_,
#     255     bound_args=bound_args,
#    (...)
#     258     tags=tags,
#     259 )
#     260 try:
# --> 261     result = func(*args, **kwargs)
#     262 except BaseException as e:
#     263     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\callbacks\utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\agent\runner\base.py:646, in AgentRunner.chat(self, message, chat_history, tool_choice)
#     641     tool_choice = self.default_tool_choice
#     642 with self.callback_manager.event(
#     643     CBEventType.AGENT_STEP,
#     644     payload={EventPayload.MESSAGES: [message]},
#     645 ) as e:
# --> 646     chat_response = self._chat(
#     647         message=message,
#     648         chat_history=chat_history,
#     649         tool_choice=tool_choice,
#     650         mode=ChatResponseMode.WAIT,
#     651     )
#     652     assert isinstance(chat_response, AgentChatResponse)
#     653     e.on_end(payload={EventPayload.RESPONSE: chat_response})
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:261, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     253 self.span_enter(
#     254     id_=id_,
#     255     bound_args=bound_args,
#    (...)
#     258     tags=tags,
#     259 )
#     260 try:
# --> 261     result = func(*args, **kwargs)
#     262 except BaseException as e:
#     263     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\agent\runner\base.py:578, in AgentRunner._chat(self, message, chat_history, tool_choice, mode)
#     575 dispatcher.event(AgentChatWithStepStartEvent(user_msg=message))
#     576 while True:
#     577     # pass step queue in as argument, assume step executor is stateless
# --> 578     cur_step_output = self._run_step(
#     579         task.task_id, mode=mode, tool_choice=tool_choice
#     580     )
#     582     if cur_step_output.is_last:
#     583         result_output = cur_step_output
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:261, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     253 self.span_enter(
#     254     id_=id_,
#     255     bound_args=bound_args,
#    (...)
#     258     tags=tags,
#     259 )
#     260 try:
# --> 261     result = func(*args, **kwargs)
#     262 except BaseException as e:
#     263     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\agent\runner\base.py:412, in AgentRunner._run_step(self, task_id, step, input, mode, **kwargs)
#     408 # TODO: figure out if you can dynamically swap in different step executors
#     409 # not clear when you would do that by theoretically possible
#     411 if mode == ChatResponseMode.WAIT:
# --> 412     cur_step_output = self.agent_worker.run_step(step, task, **kwargs)
#     413 elif mode == ChatResponseMode.STREAM:
#     414     cur_step_output = self.agent_worker.stream_step(step, task, **kwargs)
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\instrumentation\dispatcher.py:261, in Dispatcher.span.<locals>.wrapper(func, instance, args, kwargs)
#     253 self.span_enter(
#     254     id_=id_,
#     255     bound_args=bound_args,
#    (...)
#     258     tags=tags,
#     259 )
#     260 try:
# --> 261     result = func(*args, **kwargs)
#     262 except BaseException as e:
#     263     self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\callbacks\utils.py:41, in trace_method.<locals>.decorator.<locals>.wrapper(self, *args, **kwargs)
#      39 callback_manager = cast(CallbackManager, callback_manager)
#      40 with callback_manager.as_trace(trace_id):
# ---> 41     return func(self, *args, **kwargs)
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\agent\react\step.py:781, in ReActAgentWorker.run_step(self, step, task, **kwargs)
#     778 @trace_method("run_step")
#     779 def run_step(self, step: TaskStep, task: Task, **kwargs: Any) -> TaskStepOutput:
#     780     """Run step."""
# --> 781     return self._run_step(step, task)
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\agent\react\step.py:573, in ReActAgentWorker._run_step(self, step, task)
#     569 reasoning_steps, is_done = self._process_actions(
#     570     task, tools, output=chat_response
#     571 )
#     572 task.extra_state["current_reasoning"].extend(reasoning_steps)
# --> 573 agent_response = self._get_response(
#     574     task.extra_state["current_reasoning"], task.extra_state["sources"]
#     575 )
#     576 if is_done:
#     577     task.extra_state["new_memory"].put(
#     578         ChatMessage(content=agent_response.response, role=MessageRole.ASSISTANT)
#     579     )
#
# File c:\Users\billm\AppData\Local\Programs\Python\Python312\Lib\site-packages\llama_index\core\agent\react\step.py:434, in ReActAgentWorker._get_response(self, current_reasoning, sources)
#     432     raise ValueError("No reasoning steps were taken.")
#     433 elif len(current_reasoning) == self._max_iterations:
# --> 434     raise ValueError("Reached max iterations.")
#     436 if isinstance(current_reasoning[-1], ResponseReasoningStep):
#     437     response_step = cast(ResponseReasoningStep, current_reasoning[-1])
#
# ValueError: Reached max iterations.
